# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

from minisom import MiniSom

# %%
df = pd.read_csv('./data/breast_cancer.csv')
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean_fractal_dimension  ...  worst_texture  worst_perimeter  worst_area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave_points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst_symmetry  worst_fractal_dimension  class
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1:].values.ravel()

# %%
functions = ['gaussian', 'mexican_hat', 'bublle', 'triangle']
func, lr, sig = functions[3], 0.5, 3.0

som = MiniSom(x=10, y=10, input_len=30, sigma=sig, learning_rate=lr, random_seed=42, 
             neighborhood_function=func)
som.pca_weights_init(X)
som.train(X, num_iteration=1000, verbose=True)

# plots
fig, ax = plt.subplots(1, 3, figsize=(17, 5))
eq = som.quantization_error(X)
et = som.topographic_error(X)

#ax u-matrix
ax[0].imshow(som.distance_map().T, cmap='bone_r')
markers = {0: 'o', 1: 's'}
colors = {0: 'C0', 1: 'C1'}

for i, x in enumerate(X):
    w = som.winner(x)
    marker = markers[y[i]]
    color = colors[y[i]]
    ax[0].plot(w[0], w[1], marker, markerfacecolor='None',
             markeredgecolor=color, markersize=12, markeredgewidth=2)
ax[0].set_title('SOM U-Matrix Breast cancer\nlr: %s, sig: %s, erro_q: %.2f, erro_t: %.2f\nneighborhood_function: %s'%(lr, sig, eq, et, func))
# ax[0].set_xticks([]); ax[0].set_yticks([]);

#ax hitmap
freq = som.activation_response(X).astype(int)
cmap = ax[1].imshow(freq.T, cmap='Reds') 
for (i, j), z in np.ndenumerate(freq.T):
    color = 'w' if z > freq.T.max()/2 else 'k'
    ax[1].text(j, i, z, ha='center', va='center', color=color)
# ax[1].colorbar(cmap)
ax[1].set_title('SOM Hitmap Breast cancer\nlr: %s, sig: %s, erro_q: %.2f, erro_t: %.2f\nneighborhood_function: %s'%(lr, sig, eq, et, func))

#ax heatmap
dm = som.distance_map()
ax[2].imshow(dm, cmap="Reds")
# ax[2].colorbar()
for i in range(dm.shape[0]):
    for j in range(dm.shape[1]):
        color = 'w' if dm[i][j] > dm.max()/2 else 'k'
        ax[2].text(j, i, '%.2f'%dm[i][j], ha='center', va='center', color=color)
ax[2].set_title('Heatmap Breast cancer\nlr: %s, sig: %s, erro_q: %.2f, erro_t: %.2f\nneighborhood_function: %s'%(lr, sig, eq, et, func))
# Out:
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 207.73396333319164
#  topographic error: 0.4446397188049209
# Text(0.5, 1.0, 'Heatmap Breast cancer\nlr: 0.5, sig: 3.0, erro_q: 207.73, erro_t: 0.44\nneighborhood_function: triangle')

# %%
def run_som(func, lr, sig):
    som = MiniSom(x=7, y=7, input_len=30, sigma=sig, learning_rate=lr, random_seed=42, 
             neighborhood_function=func)
    som.pca_weights_init(X)
    som.train(X, num_iteration=1000, verbose=True)

    # plots
    fig, ax = plt.subplots(1, 3, figsize=(17, 5))
    eq = som.quantization_error(X)
    et = som.topographic_error(X)

    #ax u-matrix
    ax[0].imshow(som.distance_map().T, cmap='bone_r')
    markers = {0: 'o', 1: 's'}
    colors = {0: 'C0', 1: 'C1'}
    for i, x in enumerate(X):
        w = som.winner(x)
        marker = markers[y[i]]
        color = colors[y[i]]
        ax[0].plot(w[0], w[1], marker, markerfacecolor='None',
                 markeredgecolor=color, markersize=12, markeredgewidth=2)
    ax[0].set_title('SOM U-Matrix Breast cancer\nlr: %s, sig: %s, nf: %s\nerro_q: %.2f, erro_t: %.2f\n'%
                    (lr, sig, func, eq, et))
    # ax[0].set_xticks([]); ax[0].set_yticks([]);

    #ax hitmap
    freq = som.activation_response(X).astype(int)
    cmap = ax[1].imshow(freq.T, cmap='Reds') 
    for (i, j), z in np.ndenumerate(freq.T):
        color = 'w' if z > freq.T.max()/2 else 'k'
        ax[1].text(j, i, z, ha='center', va='center', color=color)
    # ax[1].colorbar(cmap)
    ax[1].set_title('SOM Hitmap Breast cancer\nlr: %s, sig: %s, nf: %s\nerro_q: %.2f, erro_t: %.2f\n'%
                    (lr, sig, func, eq, et))

    #ax heatmap
    dm = som.distance_map()
    ax[2].imshow(dm, cmap="Reds")
    # ax[2].colorbar()
    for i in range(dm.shape[0]):
        for j in range(dm.shape[1]):
            color = 'w' if dm[i][j] > dm.max()/2 else 'k'
            ax[2].text(j, i, '%.2f'%dm[i][j], ha='center', va='center', color=color)
    ax[2].set_title('Heatmap Breast cancer\nlr: %s, sig: %s, nf: %s\nerro_q: %.2f, erro_t: %.2f\n'%
                    (lr, sig, func, eq, et))
    plt.savefig('results/som_002_f%s_lr%s_sig%s.pdf'%(func, lr, sig), dpi=600, bbox_inches='tight', 
                    transparent=False, pad_inches=0.1)

funcs = ['gaussian', 'mexican_hat', 'bubble', 'triangle']
lrs = [0.1, 1.0, 2]
sigs = [1, 2, 3]

for func in funcs:
    for lr in lrs:
        for sig in sigs:
            run_som(func, lr, sig)
# Out:
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1047.8357305947188
#  topographic error: 0.3884007029876977
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1395.3312070742368
#  topographic error: 0.28822495606326887
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2008.8365698855407
#  topographic error: 0.2478031634446397
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 478.44744974734215
#  topographic error: 0.2688927943760984
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1013.5379253379162
#  topographic error: 0.23550087873462214
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2901.349797675545
#  topographic error: 0.23725834797891038
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 494.9073623175232
#  topographic error: 0.3444639718804921
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1251.278388243444
#  topographic error: 0.20913884007029876
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 5798.263443786111
#  topographic error: 0.2583479789103691
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 4818.5037662408195
#  topographic error: 0.9982425307557118
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 3422.6122653169814
#  topographic error: 0.0
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2891.496032635744
#  topographic error: 0.210896309314587
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 4466.693378254343
#  topographic error: 0.26537785588752194
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 12405.588812318982
#  topographic error: 1.0
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2159.231539316729
#  topographic error: 0.7240773286467487
#  [  819 / 1000 ]  82% - 0:00:00 left
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 4035.85120222175
#  topographic error: 0.03163444639718805
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 13759.219189457597
#  topographic error: 0.0
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2366.2352293783892
#  topographic error: 0.5852372583479789
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2949.968432696453
#  topographic error: 0.0
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1159.483551976278
#  topographic error: 0.39015817223198596
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1178.1248181673739
#  topographic error: 0.3286467486818981
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1062.9482367179874
#  topographic error: 0.033391915641476276
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 421.84333285836055
#  topographic error: 0.523725834797891
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 825.0806242524892
#  topographic error: 0.39191564147627417
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1034.844109431409
#  topographic error: 0.546572934973638
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 356.7826194158506
#  topographic error: 0.6010544815465729
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2796.156617199838
#  topographic error: 0.1616871704745167
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 4235.664090497786
#  topographic error: 0.0
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 777.4014367471873
#  topographic error: 0.35500878734622143
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 480.22322245762655
#  topographic error: 0.2618629173989455
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 1189.2013544430647
#  topographic error: 0.1195079086115993
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 245.97057717108862
#  topographic error: 0.37609841827768015
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 410.433927737498
#  topographic error: 0.3022847100175747
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 742.5690507962107
#  topographic error: 0.9982425307557118
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 208.58101225676089
#  topographic error: 0.4094903339191564
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 415.2697423136786
#  topographic error: 0.3145869947275923
# /home/adriano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
_=plt.plot(som.quantization(X)[0])
_=plt.plot(som.quantization(X)[1])
